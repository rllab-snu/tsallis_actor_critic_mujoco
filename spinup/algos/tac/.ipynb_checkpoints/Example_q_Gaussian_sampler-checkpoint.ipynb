# %%
import numpy as np
import tensorflow as tf
from tf_tsallis_statistics import *
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
tf.reset_default_graph()
mu_dummy = tf.get_variable("mu",shape=(1000,2))

q_ph = tf.placeholder(tf.float32,shape=())
x_ph = tf.placeholder(tf.float32,shape=(None,2))

log_std = tf.constant([[6.0,0.0]])
mu = tf.constant([[0.0,0.0]])
std = tf.exp(log_std) + 1e-8

x_sample = mu+std*tf_random_q_normal(tf.shape(mu_dummy),q_ph)
pdf = tf_q_gaussian_distribution(x_ph,mu,log_std,q_ph)
sess = tf.Session()

# %%
x = np.linspace(-8,8,num=100)
y = np.linspace(-8,8,num=100)
X,Y = np.meshgrid(x,y)

x_points = np.concatenate([X.reshape([-1,1]),Y.reshape([-1,1])],axis=1)

x_samples,pdf_points = sess.run([x_sample,pdf],feed_dict={x_ph:x_points,q_ph:1})
max_pdf = np.max(pdf_points[:])
pdf_points = pdf_points.reshape([100,100])
plt.plot(x_samples[:,0],x_samples[:,1],'r.')
plt.contour(X,Y,pdf_points,)
plt.plot(0.0,0.0,'rx')
plt.clim([0,max_pdf])
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.colorbar()
plt.show()

x_samples,pdf_points = sess.run([x_sample,pdf],feed_dict={x_ph:x_points,q_ph:1.5})
pdf_points = pdf_points.reshape([100,100])
plt.plot(x_samples[:,0],x_samples[:,1],'r.')
plt.contour(X,Y,pdf_points)
plt.plot(0.0,0.0,'rx')
plt.clim([0,max_pdf])
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.colorbar()
plt.show()

x_samples,pdf_points = sess.run([x_sample,pdf],feed_dict={x_ph:x_points,q_ph:2})
pdf_points = pdf_points.reshape([100,100])
plt.plot(x_samples[:,0],x_samples[:,1],'r.')
plt.contour(X,Y,pdf_points)
plt.clim([0,max_pdf])
plt.plot(0.0,0.0,'rx')
plt.xlim([-8,8])
plt.ylim([-8,8])
plt.colorbar()
plt.show()

# %%
tf.reset_default_graph()
mu_dummy = tf.get_variable("mu",shape=(1000,1))

q_ph = tf.placeholder(tf.float32,shape=())
x_ph = tf.placeholder(tf.float32,shape=(None,1))

mu = tf.constant([[0.0]])
log_std = tf.constant([[6.0]])
std = tf.exp(log_std) + 1e-8

x_sample = mu+std*tf_random_q_normal(tf.shape(x_ph),q_ph)
pdf = tf_q_gaussian_distribution(x_ph,mu,log_std,q_ph)
sess = tf.Session()

# %%
x = np.linspace(-8,8,num=1000)
x = np.reshape(x,[-1,1])

x_samples,pdf_points = sess.run([x_sample,pdf],feed_dict={x_ph:x,q_ph:1})
plt.plot(x_samples,np.zeros_like(x_samples),'r.')
plt.plot(x,pdf_points)
plt.xlim([-8,8])
plt.show()

x_samples,pdf_points = sess.run([x_sample,pdf],feed_dict={x_ph:x,q_ph:2})
plt.plot(x_samples,np.zeros_like(x_samples),'r.')
plt.plot(x,pdf_points)
plt.xlim([-8,8])
plt.show()

x_samples,pdf_points = sess.run([x_sample,pdf],feed_dict={x_ph:x,q_ph:10})
plt.plot(x_samples,np.zeros_like(x_samples),'r.')
plt.plot(x,pdf_points)
plt.xlim([-8,8])
plt.show()

# %%
tf.reset_default_graph()
# mu_dummy = tf.get_variable("mu",shape=(None,4))

q_ph = tf.placeholder(tf.float32,shape=())
x_ph = tf.placeholder(tf.float32,shape=(None,8))
x_sample = tf_random_q_normal(tf.shape(x_ph),q_ph)
sess = tf.Session()
x_samples = sess.run(tf.tanh(x_sample),feed_dict={x_ph:np.zeros((1,8)),q_ph:1})
print(x_samples)
# Out:
# [[-0.05295918 -0.97099584 -0.17695208 -0.39573786 -0.79201907 -0.18378189
#   -0.6513523   0.71569705]]
